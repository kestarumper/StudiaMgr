# %%
from string import punctuation
from stemming.porter2 import stem
import csv
import re
import math
from os import listdir
from os.path import isfile, join
from collections import Counter

# %%
def loadWords(fname):
    with open(fname, encoding="UTF-8") as file:
        return [word for line in file for word in line.split()]

stopWords = loadWords("stopwords_en.txt")
def filterWords(words):
    words = filter(lambda word: len(word) > 0, [transform(word) for word in words])
    words = difference(words, stopWords)
    return words

# %%
def difference(words, stopWords):
    return [word for word in words if word not in stopWords]

# %%
def transform(word):
    return stem(word.lower().translate(str.maketrans('', '', punctuation)))

# %%
def countOccurences(words):
    occurences = { word : 1 for word in words }
    for word in words:
        occurences[word] += 1
    return occurences

# %%
def writeCSVToFile(data, fname):
    with open(fname,'w') as out:
        csv_out=csv.writer(out)
        csv_out.writerow(['weight','word'])
        csv_out.writerows(data)
        
def writeToFile(fname, data):
    with open(fname, 'w') as out:
        out.write(data)

# %%
def divideIntoChapters(fname):
    pattern = r"####-\s*\n*(Chapter \d+\.?(\s[\w-]+)*)"
    with open(fname, 'r', encoding='UTF-8') as file:
        book = file.read()
        chapters = [term[0] for term in re.findall(pattern, book, re.IGNORECASE)]
        zipped = zip(chapters, re.split(pattern, book)[0::3][1:])
        return { name : content for name, content in zipped}

# %%
words = filterWords(loadWords("lotr.txt"))

# %%
wordDict = countOccurences(words)
pairs = list(wordDict.items())

# %%
pairs.sort(key=lambda pair: pair[1], reverse=True); pairs[:10]
# Out:
# [('frodo', 1992),
#  ('great', 1408),
#  ('long', 1382),
#  ('gandalf', 1305),
#  ('sam', 1289),
#  ('befor', 1233),
#  ('back', 1227),
#  ('dark', 1208),
#  ('time', 1050),
#  ('day', 993)]

# %%
def computeTF(wordDict):
    tfDict = {}
    bagOfWordsCount = sum(wordDict.values())
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict

# %%
def computeIDF(documents):
    N = len(documents)
    allWords = [word for document in documents for word in document.keys()]
    idfDict = dict.fromkeys(allWords, 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict

# %%
def computeTFIDF(document, idfs):
    tfidf = {}
    for word, val in document.items():
        tfidf[word] = val * idfs[word]
    return tfidf

# %%
# chapters = divideIntoChapters("lotr.txt");
# for name, content in chapters.items():
#     writeToFile("chapters/" + name + ".txt", content)

# %%
mypath = "chapters/"
chapterFileNames = [f for f in listdir(mypath) if isfile(join(mypath, f))];
documents = [countOccurences(filterWords(loadWords(mypath + fname))) for fname in chapterFileNames]

# %%
documentsTFs = [computeTF(doc) for doc in documents]
idfs = computeIDF(documents)

# %%
documentsTFIDFs = [computeTFIDF(doc, idfs) for doc in documentsTFs]

# %%
def tfidfsToData(document):
    return sorted(map(lambda pair: (math.floor(pair[1] * 100000), pair[0]), document.items()), key=lambda pair: pair[0], reverse=True)

# %%
for chapterName, document in zip(chapterFileNames, documentsTFIDFs):
    data = tfidfsToData(document)
    writeCSVToFile(data, 'weighted/' + chapterName + '.csv')

# %%
def getMerged(documents):
    allPairs = [(word, val) for doc in documentsTFIDFs for word, val in doc.items()]
    tfidf = dict.fromkeys([word for word, val in allPairs], 0)
    for word, val in allPairs:
        tfidf[word] += val
    return tfidf

# %%
mergedDocuments = getMerged(documentsTFIDFs)
writeCSVToFile(tfidfsToData(mergedDocuments), 'wordcloud_tfidf.csv')

# %%
def findWord(word):
    zipped = dict(zip(chapterFileNames, documentsTFIDFs))
    appearIn = [name for name, stats in zipped.items() if word in stats.keys()]
    return sorted([(name, math.floor(100000 * zipped[name][word])) for name in appearIn], key=lambda pair: pair[1], reverse=True)

# %%
findWord("lake")
# Out:
# [('Chapter 4. A Journey in the Dark.txt', 163),
#  ('Chapter 2.txt', 121),
#  ('Chapter 9. The Great River.txt', 107),
#  ('Chapter 7. Homeward Bound.txt', 105),
#  ('Chapter 8. The Road to Isengard.txt', 99),
#  ('Chapter 10. The Breaking of the Fellowship.txt', 88),
#  ('Chapter 1.txt', 70),
#  ('Chapter 3. Three is Company.txt', 66),
#  ('Chapter 8. Farewell to Lurien.txt', 64),
#  ('Chapter 3. The Black Gate is Closed.txt', 64),
#  ('Chapter 6. Many Partings.txt', 59),
#  ('Chapter 5. The Steward and the King.txt', 58),
#  ('Chapter 9. Flotsam and Jetsam.txt', 56),
#  ('Chapter 2. The Land of Shadow.txt', 48),
#  ('Chapter 10. The Black Gate Opens.txt', 42),
#  ('Chapter 5. A Conspiracy Unmasked.txt', 36),
#  ('Chapter 3. The Uruk-Hai.txt', 32),
#  ('Chapter 2. The Council of Elrond.txt', 29)]

# %%
allWords = filterWords(loadWords("lotr.txt"))
def nextToWord(word):
    try:
        indices = [i for i, x in enumerate(allWords) if x == word]
        wordsAfter = [allWords[i+1] for i in indices]
        return list(map(lambda pair: pair[0], sorted(Counter(wordsAfter).items(), key=lambda pair: pair[1], reverse=True)))[:5]
    except:
        return []

# %%
next5 = { word : nextToWord(word) for word in set(allWords[:1000]) }

# %%
next5
# Out:
# {'short': ['cut', 'time', 'sword', 'black', 'long'],
#  'toe': ['neat', 'fall', 'shook', 'fire', 'fight'],
#  'paint': ['shield', 'red', 'green', 'week', 'white'],
#  'fashion': ['kind', 'hill', 'mutton', 'larg', 'dwarv'],
#  'hope': ['find', 'hope', 'escap', 'left', 'ani'],
#  'move': ['slowli', 'great', 'sam', 'veri', 'frodo'],
#  'hang': ['peg', 'em', 'row', 'abov', 'twilight'],
#  'nasti': ['thing', 'littl', 'job', 'end', 'cruel'],
#  'tree': ['grew', 'tree', 'stood', 'flower', 'great'],
#  'passag': ['led', 'side', 'dwarv', 'mountain', 'lead'],
#  'begin': ['feel', 'sing', 'journey', 'understand', 'hope'],
#  'point': ['light', 'road', 'left', 'ahead', 'littl'],
#  'gasp': ['frodo', 'breath', 'sam', 'bombur', 'clutch'],
#  'life': ['hope', 'home', 'mere', 'give', 'sam'],
#  'beermug': ['pantri'],
#  'saucer': ['extra', 'green'],
#  'bathroom': ['cellar', 'mix'],
#  'chanc': ['escap', 'chanc', 'make', 'manag', 'onc'],
#  'smoker': ['morn', 'wherev', 'short', 'green', 'wind'],
#  'belt': ['tree', 'gold', 'round', 'pearl', 'hung'],
#  'follow': ['aragorn', 'day', 'bilbo', 'slowli', 'lead'],
#  'eleph': ['hear', 'gandalf'],
#  'chapter': ['1', '2', '3', '5', '7'],
#  'bedroom': ['bathroom', 'mat', 'misti', '–', 'chapter'],
#  'bow': ['low', 'head', 'ground', 'legola', 'arrow'],
#  'door': ['open', 'shut', 'close', 'mani', 'hous'],
#  'hole': ['ground', 'make', 'fill', 'dug', 'home'],
#  'profit': ['thing', 'veri', 'ani', 'peac', 'mind'],
#  'correct': ['thing', 'repli', 'littl', 'attempt', 'especi'],
#  'fairi': ['wife'],
#  'fasten': ['themselv', 'fine', 'larg', 'tree', 'rope'],
#  'scuttl': ['insid', 'cellar', 'back', 'fast', 'trunk'],
#  'dragon': ['onli', 'mountain', 'goblin', 'settl', 'pinch'],
#  'tool': ['spade', 'mountain', 'paraphernalia', 'mani', 'bundl'],
#  'ago': ['great', 'found', 'befor', 'men', 'mani'],
#  'colour': ['set', 'chiefli', 'heather', 'spark', 'fill'],
#  'expect': ['find', 'gandalf', 'dont', 'veri', 'ani'],
#  'black': ['rider', 'gate', 'shadow', 'land', 'shape'],
#  'bigger': ['bigger', 'hous', 'smoker', 'open', 'tri'],
#  'brown': ['land', 'hair', 'water', 'eye', 'leav'],
#  'nearest': ['mountain', 'point', 'peg', 'dark', 'postoffic'],
#  'warm': ['cold', 'bath', 'welcom', 'kind', 'comfort'],
#  'laugh': ['talk', 'sudden', 'grim', 'frodo', 'long'],
#  'part': ['play', 'world', 'mountain', 'stori', 'tale'],
#  'big': ['peopl', 'folk', 'man', 'littl', 'hous'],
#  'morn': ['day', 'pass', 'dawn', 'sun', 'light'],
#  'half': ['expect', 'hour', 'open', 'dream', 'mind'],
#  'undon': ['till', 'frodo'],
#  'turn': ['back', 'asid', 'round', 'left', 'frodo'],
#  'pantri': ['lot', 'onli', 'fetch', 'bring', 'floor'],
#  'arriv': ['alreadi', 'bilbo', 'fluster', 'prefer', 'point'],
#  'hair': ['head', 'long', 'flow', 'back', 'hung'],
#  'disappear': ['dark', 'dont', 'hunt', 'time', 'quiet'],
#  'appar': ['settl', 'made', 'bilbo', 'perpetu', 'chang'],
#  'sign': ['ani', 'enemi', 'dragon', 'gandalf', 'sound'],
#  'brother': ['r®mil', 'shadow', 'boromir', 'return', 'bilbo'],
#  'busi': ['themselv', 'mani', 'time', 'elsewher', 'thought'],
#  'beg': ['pardon', 'leav', 'ani', 'sam', 'back'],
#  'sake': ['sake', 'poor', 'leav', 'give', 'hunt'],
#  'shi': ['big', 'expect', 'befor', 'men', 'show'],
#  'strode': ['forward', 'time', 'mutter', 'order', 'beorn'],
#  'gracious': ['wander', 'heaven', 'thought', 'turn', 'lord'],
#  'hobbithol': ['comfort', 'part', 'built', 'hill', 'excit'],
#  'numer': ['prosper', 'today', 'inclin', 'norther', 'exceed'],
#  'remark': ['daughter', 'tale', 'hobbit', 'repeat', 'mr'],
#  'belong': ['gandalf', 'thorin', 'bless', 'victimsand', 'chapter'],
#  'baggins': ['boffin', 'live', 'undoubt', 'veri', 'welcom'],
#  'quick': ['back', 'possibl', 'frodo', 'sam', 'lightn'],
#  'money': ['found', 'wise', 'spend', 'anyth', 'didnt'],
#  'pretti': ['fair', 'ladi', 'quick', 'hopeless', 'bad'],
#  'ordinari': ['languag', 'everyday', 'adventur', 'peopl', 'aboveground'],
#  'hobbitgirl': ['unsuspect'],
#  'richer': ['belladonna', 'larger', 'tend', 'sustain', 'fruit'],
#  'insid': ['bilbo', 'door', 'hall', 'thought', 'dark'],
#  'land': ['mordor', 'mountain', 'shadow', 'empti', 'lurien'],
#  'teatim': ['tremend', 'cours', 'pour', 'long'],
#  'woolli': ['toe'],
#  'brush': ['tear', 'gandalf', 'tea', 'face', 'firwood'],
#  'put': ['hand', 'ring', 'back', 'head', 'asid'],
#  'head': ['bow', 'great', 'hand', 'fell', 'side'],
#  'live': ['thing', 'men', 'land', 'long', 'man'],
#  'break': ['day', 'em', 'fellowship', 'door', 'fast'],
#  'sir': ['sam', 'dont', 'frodo', 'understand', 'mr'],
#  'gain': ['time', 'anyth', 'shape', 'winter', 'view'],
#  'smaller': ['door', 'orc', 'beard', 'smoker', 'open'],
#  'wall': ['side', 'tower', 'rock', 'stone', 'pass'],
#  'queer': ['folk', 'inde', 'place', 'thing', 'sound'],
#  'difficult': ['find', 'hobbit', 'veri', 'make', 'danger'],
#  'horribl': ['place', 'dream', 'sound', 'deed', 'moment'],
#  'gainedwel': ['gain'],
#  'cloth': ['white', 'fold', 'silver', 'journey', 'brought'],
#  'lili': ['snapdragon', 'cri', 'friend', 'care', 'beckon'],
#  'invit': ['walk', 'begun', 'creatur', 'peopl', 'coupl'],
#  'year': ['ago', 'befor', 'sinc', 'year', 'pass'],
#  'hurri': ['forward', 'back', 'water', 'cloud', 'dont'],
#  'outsid': ['circl', 'insid', 'shire', 'dark', 'gate'],
#  'thing': ['happen', 'chang', 'thing', 'make', 'good'],
#  'fifti': ['feet', 'pace', 'year', 'leagu', 'place'],
#  'rare': ['shi', 'inde', 'object', 'curious', 'brought'],
#  'stand': ['stone', 'alon', 'door', 'head', 'tall'],
#  'beauti': ['thing', 'ladi', 'green', 'golden', 'veri'],
#  'edit': ['solid', 'opportun', 'detail', 'offer'],
#  'eyebrow': ['stuck', 'till', 'hobbit', 'mr', 'beard'],
#  'fine': ['morn', 'chain', 'fellow', 'boil', 'cloth'],
#  'share': ['treasur', 'profit', 'frodo', 'day', 'adventur'],
#  'step': ['forward', 'back', 'step', 'sat', 'insid'],
#  'neat': ['neat', 'brush', 'tie', 'pack', 'plenti'],
#  'becam': ['awar', 'veri', 'frequent', 'great', 'sudden'],
#  'dont': ['suppos', 'frodo', 'sam', 'ani', 'worri'],
#  'rescu': ['friend', 'lotho', 'princess', 'goblin', 'brought'],
#  'feel': ['veri', 'someth', 'air', 'wind', 'inclin'],
#  'friend': ['gandalf', 'long', 'mine', 'ani', 'term'],
#  'belladonna': ['remark', 'ani', 'son', 'give'],
#  'onli': ['littl', 'day', 'thing', 'small', 'time'],
#  'unexpect': ['parti', 'baggin', 'lost', 'luck', 'join'],
#  'slope': ['hill', 'abov', 'gentl', 'tree', 'ran'],
#  'seedcak': ['bake', 'dwarv'],
#  'dress': ['bright', 'green', 'sir', 'beard', 'frodo'],
#  'blew': ['loud', 'horn', 'blast', 'trumpet', 'chill'],
#  'neighbour': ['respect', 'northeast', 'live', 'meal', 'friend'],
#  'fetch': ['water', 'lamp', 'orc', 'beauti', 'island'],
#  'kind': ['strang', 'befor', 'day', 'word', 'bilbo'],
#  'low': ['voic', 'hill', 'arch', 'place', 'befor'],
#  'cross': ['river', 'bridg', 'path', 'water', 'mountain'],
#  'parti': ['busi', 'night', 'hobbit', 'present', 'gandalf'],
#  'settl': ['quiet', 'chair', 'rest', 'immov', 'burglaryespeci'],
#  'polish': ['wood', 'stone', 'chair', 'low', 'care'],
#  'midsumm': ['eve', 'morn', 'bonfir', 'mayor', 'set'],
#  'enorm': ['long', 'import', 'smoker', 'pocket', 'christma'],
#  'extra': ['cake', 'cloth', 'packag', 'weight', 'food'],
#  'fruiti': ['laugh'],
#  'tall': ['men', 'tree', 'man', 'fair', 'peak'],
#  'smell': ['air', 'feel', 'smell', 'appl', 'battl'],
#  'dare': ['move', 'cross', 'approach', 'pass', 'hope'],
#  'air': ['grew', 'full', 'light', 'thick', 'befor'],
#  'bargain': ['pipe', 'alreadi', 'futur', 'bilbo', 'noth'],
#  'sinc': ['left', 'day', 'night', 'ani', 'great'],
#  'tuck': ['golden', 'darkest', 'hear', 'root', 'armpit'],
#  'bushi': ['eyebrow', 'twiggi'],
#  'rush': ['wind', 'round', 'forward', 'past', 'follow'],
#  'run': ['river', 'back', 'water', 'swift', 'fast'],
#  'hobbit': ['shire', 'sat', 'frodo', 'walk', 'turn'],
#  'mrs': ['maggot', 'cotton', 'bungo', 'smith'],
#  'idea': ['suggest', 'busi', 'possibl', 'thought', 'front'],
#  'finger': ['ring', 'goblin', 'frodo', 'gandalf', 'tight'],
#  'fill': ['light', 'air', 'water', 'room', 'dread'],
#  'beer': ['barrel', 'eastfarth', 'suit', 'cake', 'walk'],
#  'ani': ['rate', 'case', 'longer', 'hope', 'time'],
#  'excus': ['jomer', 'part', 'hobbit', 'left', 'slide'],
#  'ancestor': ['fairi', 'thrain', 'elrond', 'heir'],
#  'diamond': ['stud', 'rare', 'waistcoat', 'frodo', 'fire'],
#  'wherev': ['fare', 'extraordinari', 'told', 'quick', 'find'],
#  'visitor': ['tunnel', 'befor', 'busi', 'hang', 'invit'],
#  'dinner': ['day', 'can’t', 'sinc', 'began', 'good'],
#  'silver': ['gold', 'white', 'belt', 'star', 'fountain'],
#  'bright': ['eye', 'sword', 'blue', 'fire', 'mail'],
#  'flower': ['garden', 'white', 'open', 'befor', 'tree'],
#  'engag': ['tablet', 'kill', 'sport', 'interior', 'fenc'],
#  'immov': ['curious', 'thin', 'awar'],
#  '1': ['concern', 'longexpect', 'mani', 'departur', 'tame'],
#  'boot': ['yellow', 'mani', 'good', 'tree', 'cours'],
#  'prefer': ['round', 'horribl', 'cold', 'defend', 'point'],
#  'howev': ['toler', 'high', 'long', 'meanwhil', 'noth'],
#  'smoke': ['steam', 'rose', 'rise', 'dark', 'air'],
#  'cur': ['head', 'long', 'part', 'master'],
#  'pint': ['beermug', 'beer', 'wellearn'],
#  'baggin': ['bag', 'hate', 'ani', 'dont', 'hobbit'],
#  'stuff': ['pippin', 'guess', 'befor', 'head', 'mountain'],
#  'makeup': ['side'],
#  'float': ['back', 'stream', 'slowli', 'wind', 'cloud'],
#  'rid': ['smaug', 'leav', 'wont', 'dragon', 'littl'],
#  'eye': ['eye', 'frodo', 'turn', 'thought', 'dark'],
#  'wizard': ['vale', 'gandalf', 'head', 'hand', 'voic'],
#  'prosi': ['believ'],
#  'snapdragon': ['laburnum', 'sunflow'],
#  'mr': ['frodo', 'baggin', 'butterbur', 'bilbo', 'underhil'],
#  'magic': ['ring', 'strong', 'door', 'shut', 'ordinari'],
#  'thumb': ['brace', 'good', 'thought'],
#  'talk': ['time', 'gandalf', 'togeth', 'talk', 'hobbit'],
#  'panel': ['wall'],
#  'bad': ['end', 'time', 'news', 'wors', 'dream'],
#  'fluster': ['anyth', 'bad', 'answer', 'great', 'eggquest'],
#  'puf': ['passag', 'mat', 'bywat', 'rush', 'pant'],
#  'neighbourhood': ['hill', 'hero', 'queerexcept', 'includ', 'peopl'],
#  'perfect': ['round', 'ordinari', 'safe', 'beauti', 'true'],
#  'blue': ['flame', 'sky', 'hood', 'eye', 'air'],
#  'mile': ['mile', 'north', 'befor', 'road', 'bridg'],
#  'devot': ['cloth', 'admir'],
#  '«i': ['part'],
#  'can’t': ['anybodi'],
#  'pleas': ['dont', 'care', 'hobbit', 'ring', 'rememb'],
#  'hung': ['chain', 'dragonfir', 'neck', 'knee', 'short'],
#  'clever': ['hobbit', 'brown', 'tunnel', 'eyes', 'bit'],
#  'plain': ['mr', 'hobbit', 'frodo', 'clear', 'veri'],
#  'stud': ['fasten', 'bring', 'gem', 'flask', 'white'],
#  'stomach': ['dress', 'felt', 'wag', 'feel', 'hoist'],
#  'giant': ['rock', 'oak', 'spider', 'rescu', 'guffaw'],
#  'great': ['river', 'gate', 'ring', 'deal', 'stone'],
#  'altogeth': ['dark', 'alon', 'unexpect', 'bewild', 'good'],
#  'fond': ['dwarv', 'inde', 'bilbo', 'visitor', 'flower'],
#  'stick': ['togeth', 'plan', 'walk', 'back', 'gaze'],
#  'deep': ['breath', 'thought', 'dark', 'water', 'place'],
#  'loud': ['voic', 'clear', 'cri', 'yell', 'nois'],
#  'bless': ['mr', 'realm', 'gim', 'life', 'thorin'],
#  'red': ['light', 'eye', 'book', 'glow', 'fire'],
#  'age': ['world', 'ago', 'age', 'befor', 'past'],
#  'bag': ['end', 'tool', 'brought', 'bilbo', 'troll'],
#  'peg': ['hat', 'dwalin', 'march', 'quit'],
#  'comfort': ['thing', 'sit', 'gim', 'chair', 'leav'],
#  'wait': ['till', 'time', 'moment', 'long', 'gandalf'],
#  'anoth': ['long', 'thing', 'day', 'anoth', 'night'],
#  'river': ['flow', 'run', 'bank', 'valley', 'back'],
#  'feet': ['high', 'abov', 'great', 'ground', 'hand'],
#  'hop': ['door', 'danc', 'insid', 'fal', 'home'],
#  'wooden': ['hous', 'box', 'pipe', 'gate', 'spoon'],
#  'natur': ['leatheri', 'firefor', 'gollum', 'folk', 'dwarv'],
#  'eve': ['splendid', 'earli', 'crescent', 'morn', 'parti'],
#  'tablet': ['gandalf', 'writ'],
#  'dirti': ['work', 'wet', 'hammer', 'tatter', 'rag'],
#  'read': ['book', 'word', 'riddl', 'sign', 'mani'],
#  'bare': ['bone', 'rocki', 'time', 'tabl', 'head'],
#  'convers': ['began', 'end', 'smaug', 'older', 'green'],
#  'pair': ['magic', 'mind', 'bombur', 'everi', 'yellow'],
#  'princess': ['unexpect'],
#  'carpet': ['provid', 'forest', 'deep'],
#  'goblin': ['wolv', 'big', 'great', 'grab', 'ani'],
#  'surpris': ['bilbo', 'dwarv', 'dont', 'delight', 'happen'],
#  'water': ['flow', 'fell', 'edg', 'deep', 'side'],
#  'folk': ['call', 'dwell', 'pass', 'shire', 'mani'],
#  'call': ['back', 'frodo', 'call', 'gandalf', 'hobbit'],
#  'onc': ['time', 'long', 'dark', 'befor', 'back'],
#  'dwalin': ['balin', 'servic', 'green', 'talk', 'door'],
#  'veri': ['good', 'long', 'great', 'littl', 'veri'],
#  'themselv': ['afraid', 'wide', 'ground', 'long', 'fell'],
#  'stuck': ['brim', 'hand', 'pin', 'thumb', 'howev'],
#  'rich': ['pleasant', 'veri', 'carv', 'reward', 'fair'],
#  'button': ['doorstep', 'door', 'pot', 'wedg', 'burst'],
#  'quarter': ['hour', 'heard', 'peopl', 'eastfarth', 'farth'],
#  'mind': ['bodi', 'light', 'doe', 'memori', 'thing'],
#  'meadow': ['slope', 'green', 'pass', 'villag', 'thinclad'],
#  'breakfast': ['gandalf', 'readi', 'onli', 'veri', 'sam'],
#  'dwarf': ['gim', 'dare', 'legola', 'elv', 'fact'],
#  'round': ['corner', 'round', 'door', 'window', 'great'],
#  'began': ['sing', 'climb', 'fall', 'move', 'feel'],
#  'brass': ['button', 'knob', 'ring'],
#  'goodby': ['frodo', 'gandalf', 'elrond', 'good', 'present'],
#  'worm': ['dread', 'saruman', 'oozi', 'call', 'weak'],
#  'floor': ['tunnel', 'leav', 'forest', 'inde', 'high'],
#  'porthol': ['paint'],
#  'blunder': ['make', 'frantic', 'tire', 'thorin', 'develop'],
#  'moment': ['thought', 'sam', 'pippin', 'stood', 'silenc'],
#  'oozi': ['smell'],
#  'tunnel': ['made', 'goblin', 'long', 'open', 'dark'],
#  'absurd': ['someth', 'enemi', 'pleas', 'laugh', 'contempt'],
#  'sat': ['silent', 'besid', 'side', 'ground', 'dark'],
#  'curious': ['chanc', 'key', 'made', 'otherwis', 'excit'],
#  'hall': ['fire', 'fill', 'father', 'beneath', 'becam'],
#  'cloak': ['hood', 'blanket', 'lurien', 'silver', 'cast'],
#  'ad': ['low', 'touch', 'tea', 'swept', 'part'],
#  'perhap': ['find', 'sam', 'understand', 'onli', 'doe'],
#  'alreadi': ['draw', 'mani', 'frodo', 'heard', 'men'],
#  'coat': ['mail', 'glisten', 'hobbit', 'bombur', 'waistcoat'],
#  'carri': ['back', 'frodo', 'torch', 'great', 'boat'],
#  'middl': ['night', 'door', 'floor', 'stream', 'road'],
#  'respect': ['onli', 'gainedwel', 'baggins', 'person', 'countri'],
#  'mine': ['moria', 'gandalf', 'rivendel', 'work', 'whi'],
#  'respons': ['mani', 'good', 'cours', 'sinc', 'command'],
#  'father': ['son', 'father', 'grandfath', 'rememb', 'isildur'],
#  'earth': ['sky', 'happen', 'fall', 'haldir', 'ani'],
#  'remain': ['long', 'strength', 'aliv', 'guard', 'silent'],
#  'entir': ['hobbitlik', 'accid', 'mighti', 'turn', 'differ'],
#  'found': ['themselv', 'path', 'lie', 'thing', 'ring'],
#  'grass': ['grow', 'grey', 'deep', 'side', 'flower'],
#  'sell': ['button', 'auction', 'bag', 'beauti', 'arrang'],
#  'word': ['saruman', 'spoken', 'speak', 'befor', 'long'],
#  'tubeshap': ['hall'],
#  'host': ['mordor', 'pass', 'enemi', 'rohan', 'isengard'],
#  'lass': ['blue', 'daisi', 'king', 'wellworn', 'hadnt'],
#  'especi': ['food', 'long', 'sinc', 'friend', 'frodo'],
#  'make': ['hast', 'mind', 'ani', 'song', 'good'],
#  'shoe': ['becaus', 'river', 'chose', 'sinc', 'fish'],
#  'sole': ['thick', 'benefit', 'profession', 'clad', 'command'],
#  'meant': ['back', 'kill', 'prison', 'stop', 'supper'],
#  'decid': ['cours', 'leav', 'decid', 'time', 'make'],
#  'morsel': ['back', 'itd', 'hand', 'grey', 'save'],
#  'world': ['outsid', 'chang', 'young', 'end', 'mani'],
#  'elv': ['men', 'dwarv', 'sir', 'call', 'time'],
#  'seat': ['amon', 'silenc', 'stool', 'befor', 'black'],
#  'breast': ['beneath', 'drew', 'held', 'bilbo', 'freckl'],
#  'afternoon': ['walk', 'sam', 'wear', 'late', 'sun'],
#  'frontdoor': ['bell', 'strode', 'fine', 'lobelia', 'mani'],
#  'larg': ['flat', 'heavi', 'round', 'bear', 'stone'],
#  'sail': ['ship', 'sail', 'sea', 'cloud', 'west'],
#  'suppos': ['ani', 'time', 'frodo', 'mr', 'havent'],
#  'eat': ['drink', 'togeth', 'littl', 'fish', 'hors'],
#  'ran': ['back', 'forward', 'wild', 'tree', 'side'],
#  'undoubt': ['richer', 'brought', 'hot', 'fallen'],
#  'arrang': ['veri', 'meet', 'unnecessari', 'comfort', 'stone'],
#  'nois': ['wind', 'water', 'great', 'thunder', 'distanc'],
#  'wednesday': ['yesterday', 'rememb', 'teatim', 'eve'],
#  'staff': ['head', 'aloft', 'stood', 'broken', 'gandalf'],
#  'scarf': ['white', 'long', 'swath'],
#  'knew': ['noth', 'gandalf', 'littl', 'happen', 'someth'],
#  'prepar': ['await', 'move', 'time', 'answer', 'ani'],
#  'laburnum': ['fire'],
#  'grandfath': ['thror', 'sake', 'thorin', 'king', 'hall'],
#  'escap': ['ani', 'dark', 'orc', 'onli', 'run'],
#  'havent': ['ani', 'told', 'time', 'chang', 'lost'],
#  'white': ['tower', 'hors', 'mountain', 'light', 'rider'],
#  'shine': ['eye', 'clear', 'bright', 'sky', 'frodo'],
#  'question': ['answer', 'long', 'whi', 'bilbo', 'gandalf'],
#  'face': ['grew', 'eye', 'mountain', 'downward', 'troubl'],
#  'day': ['befor', 'ago', 'pass', 'day', 'end'],
#  'morning': ['belladonna'],
#  'brim': ['shadi', 'hat', 'breath', 'forest'],
#  'lost': ['lost', 'count', 'time', 'sight', 'thought'],
#  'hear': ['voic', 'word', 'sound', 'hear', 'cri'],
#  'push': ['pull', 'back', 'insid', 'bilbo', 'chair'],
#  'brace': ['blew', 'feet', 'young', 'frodo'],
#  'bake': ['afternoon', 'trillillillolli', 'toast', 'light'],
#  'green': ['grass', 'field', 'hill', 'mound', 'dragon'],
#  'place': ['time', 'great', 'befor', 'frodo', 'pippin'],
#  'rude': ['wizard', 'interrupt', 'rude', 'eagl', 'heard'],
#  'gave': ['cri', 'back', 'long', 'great', 'frodo'],
#  'front': ['gate', 'door', 'frodo', 'pippin', 'road'],
#  'mother': ['hobbit', 'side', 'elder', 'youngest', 'kin'],
#  'quiet': ['sam', 'day', 'peac', 'frodo', 'voic'],
#  'shadi': ['hat', 'mountain', 'pool'],
#  'scarlet': ['flame', 'hood', 'lightn', 'stone', 'ear'],
#  'find': ['ring', 'path', 'ani', 'anyth', 'someth'],
#  'dear': ['friend', 'frodo', 'bilbo', 'fellow', 'hobbit'],
#  'caught': ['glimps', 'sight', 'glint', 'fire', 'breath'],
#  'leg': ['arm', 'carri', 'ach', 'pippin', 'ankl'],
#  'shut': ['eye', 'door', 'mouth', 'yer', 'light'],
#  'good': ['deal', 'night', 'morn', 'luck', 'mani'],
#  'upset': ['thing', 'fair', 'thought', 'spider', 'sam'],
#  'hea': ['host', 'turn', 'ds', 'ling', 'led'],
#  'climb': ['tree', 'high', 'top', 'back', 'long'],
#  'sort': ['thing', 'remark', 'frodo', 'good', 'disappear'],
#  'dwarv': ['men', 'bilbo', 'make', 'hobbit', 'heard'],
#  'knob': ['exact', 'bexr', 'joint', 'pit', 'solemn'],
#  'fright': ['hear', 'gandalf', 'pleas', 'excit', 'noth'],
#  'provid': ['polish', 'poni', 'skin', 'bitter', 'king'],
#  'cake': ['drink', 'begin', 'ran', 'anoth', 'run'],
#  'welltodo': ['hobbit', 'construct'],
#  'foot': ['hill', 'tree', 'stair', 'foot', 'water'],
#  'mani': ['thing', 'year', 'men', 'time', 'mile'],
#  'disturb': ['bilbo', 'peac', 'rest', 'uncomfort', 'esteem'],
#  'window': ['open', 'dark', 'west', 'tower', 'doe'],
#  'unsuspect': ['bilbo'],
#  'notic': ['time', 'dark', 'man', 'hobbit', 'great'],
#  'hat': ['long', 'leap', 'coat', 'good', 'hang'],
#  'balin': ['dwalin', 'fili', 'son', 'tomb', 'lord'],
#  'bell': ['rang', 'ring', 'clang', 'place', 'find'],
#  'cakeseedcak': ['ani'],
#  'kitchen': ['diningroom', 'fili', 'tri', 'everi', 'befor'],
#  'anyth': ['els', 'happen', 'wrong', 'gollum', 'eat'],
#  'blow': ['horn', 'smoker', 'ani', 'reckon', 'door'],
#  'lot': ['thing', 'bilbo', 'lot', 'guess', 'found'],
#  'splendid': ['frodo', 'laugh', 'great', 'white', 'wear'],
#  'famili': ['histori', 'time', 'long', 'bilbo', 'inde'],
#  'shini': ['yellow'],
#  'luck': ['turn', 'back', 'inde', 'courag', 'day'],
#  'pipe': ['sit', 'tobacco', 'blew', 'pack', 'reach'],
#  'consid': ['claim', 'veri', 'troubl', 'hunt', 'weighti'],
#  'side': ['side', 'river', 'hill', 'great', 'road'],
#  '’¥a': ['wednesday'],
#  'lean': ['back', 'staff', 'forward', 'stick', 'face'],
#  'believ': ['frodo', 'onc', 'tale', 'call', 'gandalf'],
#  'lad': ['frodo', 'lass', 'day', 'veri', 'bilbo'],
#  'chair': ['door', 'back', 'befor', 'hall', 'carven'],
#  'open': ['eye', 'door', 'window', 'mouth', 'gate'],
#  'wife': ['cours', 'child', 'live', 'buckland', 'drownd'],
#  'grow': ['light', 'dim', 'wood', 'fear', 'stronger'],
#  'spike': ['staff', 'rock', 'southward', 'larg', 'nice'],
#  'everyday': ['sort'],
#  'hood': ['cloak', 'grey', 'hang', 'balin', 'abov'],
#  'breath': ['deep', 'air', 'loud', 'hiss', 'soft'],
#  'tookclan': ['adventur'],
#  'whi': ['didnt', 'whi', 'dont', 'leav', 'left'],
#  'mad': ['leap', 'dare', 'baggin', 'men', 'denethor'],
#  'inter': ['upset'],
#  'solid': ['comfort', 'gold', 'farmhous', 'wall', 'ground'],
#  'tri': ['find', 'back', 'onc', 'escap', 'save'],
#  'lefthand': ['side', 'foul', 'wall'],
#  'explan': ['tabl', 'thorin', 'explain', 'stand', 'inno'],
#  'wound': ['round', 'back', 'slowli', 'heal', 'frodo'],
#  'matter': ['fact', 'concern', 'great', 'speak', 'elrond'],
#  'plump': ['beer', 'bump'],
#  'spade': ['hop', 'woollen', 'serv'],
#  'sit': ['besid', 'doorstep', 'chair', 'back', 'quiet'],
#  'luxuri': ['hobbithol', 'version', 'obtain'],
#  'adventur': ['befor', 'anyth', 'found', 'veri', 'day'],
#  'inde': ['gandalf', 'onli', 'time', 'frodo', 'answer'],
#  'tale': ['told', 'long', 'tale', 'end', 'bilbo'],
#  'louder': ['fire', 'nearer', 'ring', 'run', 'sssss'],
#  'descript': ['nowaday', 'sever', 'gollum', 'befor', 'word'],
#  'thought': ['heard', 'thing', 'frodo', 'onli', 'sudden'],
#  'upstair': ['hobbit', 'ani', 'window'],
#  'height': ['abov', 'strong', 'east', 'great', 'guess'],
#  'dri': ['fruit', 'leav', 'grass', 'bare', 'cloth'],
#  'oldlook': ['dwarf'],
#  'hard': ['believ', 'cold', 'reach', 'dare', 'rock'],
#  'silenc': ['fell', 'frodo', 'broken', 'sudden', 'follow'],
#  'tomorrow': ['ride', 'morn', 'tomorrow', 'day', 'leav'],
#  'bother': ['ani', 'stori', 'grow', 'veri', 'wake'],
#  'beard': ['grow', 'wag', 'dwarv', 'veri', 'durin'],
#  'fact': ['veri', 'great', 'bilbo', 'alreadi', 'dont'],
#  'tobacco': ['door', 'parti', 'someth', 'brought', 'southfarth'],
#  'br': ['br', 'ight', 'unexpect', 'roast', 'jump'],
#  'golden': ['wood', 'hall', 'flower', 'ring', 'hair'],
#  'send': ['word', 'messag', 'back', 'mr', 'stone'],
#  'bit': ['bilbo', 'queer', 'thing', 'bit', 'work'],
#  'garden': ['full', 'arrang', 'thing', 'meadow', 'cluster'],
#  'poor': ['littl', 'smjagol', 'bilbo', 'mr', 'bill'],
#  'sprout': ['place', 'littl', 'foul', 'grow'],
#  'uninvit': ['dwarf', 'chanc', 'unexpect', 'water', 'moment'],
#  'order': ['thing', 'carri', 'fellow', 'shire', 'mani'],
#  'fast': ['asleep', 'strong', 'sick', 'land', 'sam'],
#  'gandalf': ['grey', 'laugh', 'aragorn', 'time', 'hope'],
#  'son': ['arathorn', 'elrond', 'gluin', 'drogo', 'thengel'],
#  'someon': ['els', 'intellig', 'share', 'door', 'sens'],
#  'nowaday': ['sinc', 'grandfath', 'outsid', 'sorri', 'place'],
#  'drink': ['laugh', 'water', 'fill', 'ani', 'drink'],
#  'letter': ['frodo', 'elvish', 'begin', 'cun', 'fortun'],
#  'reach': ['top', 'rivendel', 'stair', 'mountain', 'path'],
#  'scratch': ['head', 'queer', 'pinch', 'hot', 'sign'],
#  'sandi': ['hole', 'floor'],
#  '…': ['hobbit'],
#  'member': ['compani', 'tookclan', 'import', 'studi', 'fellowship'],
#  'today': ['tonight', 'tomorrow', 'pippin', 'mani', 'day'],
#  'back': [],
#  'anybodi': ['make', 'them»', 'acquaint', 'bilbo', 'els'],
#  'wardrob': ['room'],
#  'darkgreen': ['hood', 'cloak'],
#  'daughter': ['elrond', 'king', 'head', 'answer', 'mr'],
#  'answer': ['gandalf', 'frodo', 'aragorn', 'question', 'strider'],
#  'els': ['answer', 'move', 'good', 'noth', 'shire'],
#  'duti': ['stuck', 'turn', 'neglect', 'presid', 'goodby'],
#  'excel': ['firework', 'audaci', 'gandalf', 'littl', 'poni'],
#  'hand': ['hand', 'held', 'sam', 'frodo', 'breast'],
#  'meantim': ['tri', 'stand', 'famish', 'content', 'someth'],
#  'exact': ['middl', 'edit', 'situat', 'side', 'thorin'],
#  'pray': ['littl', 'dont', 'frodo', 'yon', 'interrupt'],
#  'anyon': ['els', '«i', 'live', 'veri', 'guard'],
#  'yellow': ['face', 'leav', 'hair', 'light', 'red'],
#  'cup': ['hand', 'saucer', 'toymarket', 'heavi', 'chief'],
#  'leatheri': ['sole'],
#  'goodnatur': ['face', 'beauti'],
#  'pardon': ['put', 'sam', 'master', 'thought', 'mr'],
#  'forgotten': ['everyth', 'men', 'long', 'mountain', 'heard'],
#  'becom': ['veri', 'dark', 'import', 'crowd', 'onli'],
#  'kettl': ['put', 'begin', 'sing', 'boil', 'onand'],
#  'tea': ['ani', 'time', 'pantri', 'pray', 'manag'],
#  'someth': ['els', 'happen', 'eat', 'strang', 'voic'],
#  'room': ['spare', 'merri', 'found', 'littl', 'fire'],
#  'built': ['long', 'fire', 'great', 'tower', 'hous'],
#  'wont': ['find', 'ani', 'hurt', 'give', 'talk'],
#  'cellar': ['pantri', 'fill', 'dwarv', 'mansion', 'stood'],
#  'wear': ['frodo', 'ring', 'find', 'black', 'shoe'],
#  'firework': ['gandalf', 'rememb', 'kind', 'glare', 'midsummerev'],
#  'discreet': ['disappear'],
#  'die': ['light', 'day', 'dark', 'battl', 'sam'],
#  'man': ['gondor', 'willow', 'moon', 'eye', 'walk'],
#  'befor': ['long', 'gate', 'feet', 'eye', 'end'],
#  'grown': ['long', 'veri', 'great', 'sinc', 'fifti'],
#  'wander': ['aimless', 'wild', 'lost', 'road', 'wood'],
#  'shore': ['lake', 'anduin', 'sea', 'river', 'mani'],
#  'prosper': ['bilbo', 'part', 'wealthi', 'guard', 'wealth'],
#  'ring': ['power', 'frodo', 'ring', 'finger', 'hand'],
#  'rate': ['hobbit', 'veri', 'thought', 'pippin', 'give'],
#  'stupid': ['folk', 'bolger', 'dull', 'sudden', 'kind'],
#  'thick': ['leg', 'bush', 'hedg', 'warm', 'abov'],
#  'openbilbo': ['hard'],
#  'sorri': ['frodo', 'bilbo', 'leav', 'mr', 'dont'],
#  'hobbitlik': ['onc', 'invent'],
#  'stood': ['silent', 'befor', 'besid', 'moment', 'great'],
#  'straight': ['back', 'grey', 'ahead', 'stair', 'road'],
#  'fair': ['folk', 'face', 'hous', 'ladi', 'morn'],
#  'chiefli': ['green', 'curs', 'cram', 'arkenston', 'unpleas'],
#  'extraordinari': ['fashion', 'face'],
#  'sight': ['land', 'sound', 'dark', 'time', 'frodo'],
#  'end': ['day', 'long', 'gandalf', 'end', 'bilbo'],
#  'deepset': ['round'],
#  'widow': ['son', 'orphan', 'rumbl'],
#  'late': ['afternoon', 'night', 'breakfast', 'guess', 'morn'],
#  'littl': ['hope', 'peopl', 'fellow', 'hobbit', 'food'],
#  'immens': ['black', 'fat', 'rich', 'antiqu', 'fond'],
#  'ground': ['beneath', 'befor', 'fell', 'sam', 'besid'],
#  'stiff': ['neck', 'leg', 'perhap', 'desper', 'goblin'],
#  'suit': ['good', 'laugh', 'breeland', 'excus', 'aint'],
#  'fire': ['burn', 'leap', 'die', 'smoke', 'frodo'],
#  'aftersupp': ['morsel'],
#  'noth': ['els', 'happen', 'noth', 'move', 'frodo'],
#  'wet': ['cold', 'hole', 'loneland', 'begin', 'mutter'],
#  'fabul': ['belladonna', 'rich'],
#  'gaze': ['frodo', 'eastward', 'ahead', 'north', 'back'],
#  'diningroom': ['floor', 'nobodi', 'time', 'open', 'long'],
#  'till': ['morn', 'late', 'bilbo', 'sun', 'caught'],
#  'rememb': ['onli', 'gandalf', 'littl', 'mani', 'word'],
#  'bungo': ['baggin', 'bilbo', 'thought'],
#  'peopl': ['long', 'frodo', 'north', 'world', 'citi'],
#  'twilight': ['frodo', 'tree', 'notic', 'green', 'hall'],
#  'uncomfort': ['feel', 'sleep', 'thing', 'littl', 'ad'],
#  'amus': ['veri', 'talk', 'wolv', 'delight', 'wicked'],
#  'becaus': ['onli', 'felt', 'evil', 'ani', 'small'],
#  'time': ['befor', 'thought', 'pass', 'bilbo', 'ago'],
#  'yesterday': ['morn', 'fluster', 'mutton', 'key', 'frodo'],
#  'cours': ['gandalf', 'answer', 'bilbo', 'onli', 'thorin'],
#  'sun': ['shine', 'shone', 'climb', 'moon', 'sink'],
#  'fellow': ['veri', 'gandalf', 'merri', 'conspir', 'bob'],
#  'quit': ['long', 'differ', 'sudden', 'forgotten', 'safe'],
#  'small': ['dark', 'thing', 'sword', 'silver', 'red'],
#  'hill': ['hill', 'long', 'top', 'emyn', 'water'],
#  'stori': ['ani', 'day', 'bilbo', 'long', 'true'],
#  'probabl': ['make', 'great', 'frodo', 'onli', 'bilbo'],
#  'tabl': ['chair', 'gandalf', 'hall', 'hand', 'fell'],
#  'describ': ['fact', 'tale', 'nod', 'thing', 'good'],
#  'begun': ['arriv', 'veri', 'grow', 'long', 'feel'],
#  'inclin': ['stomach', 'filter', 'grumbl', 'cheer', 'truth'],
#  'long': ['ago', 'time', 'befor', 'year', 'sinc'],
#  'waist': ['immens', 'eye', 'mishap', 'worn', 'leg'],
#  'tile': ['carpet'],
#  'grey': ['cloak', 'light', 'shadow', 'hood', 'haven'],
#  'finish': ['book', 'sam', 'speak', 'breakfast', 'stori'],
#  'them»': ['mr'],
#  'behav': ['exact', 'onli', 'worst', 'ill', 'foolish'],
#  'ship': ['sail', 'built', 'bear', 'lie', 'great'],
#  'hobbitboy': ['hobbitgirl', 'tri'],
#  'pretend': ['notic', 'hide', 'understand', 'goblin', 'polit'],
#  'servic': ['dwarv', 'master', 'famili', 'dark', 'low'],
#  'painfulh': ['tea'],
#  'tremend': ['excit', 'ring', 'goblin', 'driver', 'pace'],
#  'bilbo': ['baggin', 'frodo', 'veri', 'heard', 'knew'],
#  'hush': ['fell', 'gandalf', 'hush', 'frodo', 'whisper'],
#  'give': ['leav', 'good', 'back', 'ring', 'news'],
#  'manag': ['good', 'find', 'time', 'deep', 'dwarv'],
#  'visit': ['elv', 'land', 'shire', 'bill', 'fangorn'],
#  'heard': ['sound', 'voic', 'befor', 'cri', 'nois']}
